# %%
import pandas as pd

# %%
df = pd.read_excel('Wygenerowane Dane.xlsx')
X = df[[ 'L', 'R', 'G', 'Rm', 'HB']]
y = df['ap']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
import pickle
with open('modelRF[ap]', 'wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.metrics import  r2_score
r2_score(y_test, y_predict)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_predict, alpha=0.3)

plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
pred_df = pd.DataFrame({'Actual value':y_test, 'Predicted value':y_predict, 'Difference': y_test-y_predict})
pred_df[0:20]
# Out:
#      Actual value  Predicted value    Difference
# 386           1.2              1.2 -1.998401e-15
# 2             1.6              1.6  2.886580e-15
# 546           0.8              0.8  1.443290e-15
# 757           0.2              0.2  3.885781e-16
# 548           2.2              2.2  3.552714e-15
# 379           2.2              2.2  3.552714e-15
# 240           3.2              3.2  5.773160e-15
# 363           0.2              0.2  3.885781e-16
# 58            0.8              0.8  1.443290e-15
# 15            3.6              3.6 -3.108624e-15
# 501           3.6              3.6 -3.108624e-15
# 170           1.8              1.8 -1.554312e-15
# 143           1.8              1.8 -1.554312e-15
# 287           0.8              0.8  1.443290e-15
# 995           1.2              1.2 -1.998401e-15
# 187           1.0              1.0  0.000000e+00
# 329           2.2              2.2  3.552714e-15
# 442           2.0              2.0  0.000000e+00
# 524           0.5              0.5  0.000000e+00
# 500           1.0              1.0  0.000000e+00

# %%
import pickle
with open('modelRF[ap]', 'wb') as f:
    pickle.dump(model,f)
