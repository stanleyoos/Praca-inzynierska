# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Wygenerowane Dane.xlsx')
X = df[[ 'L', 'R', 'G', 'Rm', 'HB']]
y = df['pz']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
from sklearn import tree
model = tree.DecisionTreeRegressor()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score #
y_pred = model.predict(X_train)
lin_mse = mean_squared_error(y_train, y_pred)
lin_rmse = np.sqrt(lin_mse)
lin_rmse


import pickle
with open('modelDT[pz]', 'wb') as f:
    pickle.dump(model,f)

# %%
r2_score(y_test, y_predict)
# Out:
# 0.9953752593734987

# %%
from sklearn.metrics import mean_squared_error, r2_score #
y_pred = model.predict(X_train)
lin_mse = mean_squared_error(y_train, y_pred)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 1.179561852415395e-17

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_predict, alpha=0.3)

plt.xlabel('Wartość poprawna')
plt.ylabel('Wyliczona przez model')
plt.title('Drzewo decyzyjne fz [mm/ostrze] - 1000 rowków')
# Out:
# Text(0.5, 1.0, 'Drzewo decyzyjne fz [mm/ostrze] - 1000 rowków')

# %%
import pickle
with open('modelDT[pz]', 'wb') as f:
    pickle.dump(model,f)
